# %% [markdown]
# # example

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
gt = np.load("./results/2019-08-23_002_gt.npy", allow_pickle=True)

# %%
# gt keys:
# image
# cmfs

gt_img  = gt.item().get('image')
gt_cmfs = gt.item().get('cmfs')

# %%
# view cmfs

plt.plot(gt_cmfs["wavelengths"], gt_cmfs["values"])
plt.show()

# %%
from utils.XYZ_to_SRGB import XYZ_TO_SRGB

# %%
SRGB = XYZ_TO_SRGB()

# %%
sRGB_img = SRGB.XYZ_to_sRGB(gt_img.T)
# Out:
# D:\Jupyter\HW\Color Image\utils\XYZ_to_SRGB.py:27: UserWarning: ffs, use float32 not float64
#   warnings.warn("ffs, use float32 not %s" % img.dtype)
# D:\Jupyter\HW\Color Image\utils\XYZ_to_SRGB.py:29: UserWarning: ffs, the range should be in [0, 1] not [-0.009113 2.861412]
#   warnings.warn(

# %%
plt.imshow(sRGB_img)

# %%
sample = np.load("./results/2019-08-23_002_sample.npy", allow_pickle=True)

# %%
# sample keys:
# image
# cmfs
# light
# bayer
# mean
# sigma

sample_img  = sample.item().get('image')
sample_cmfs = sample.item().get('cmfs')
sample_light = sample.item().get('light')
sample_bayer = sample.item().get('bayer')
sample_mean = sample.item().get('mean')
sample_sigma = sample.item().get('sigma')

# %%
plt.imshow(sample_img)

# %%
# view cmfs

plt.plot(sample_cmfs["wavelengths"], sample_cmfs["values"])
plt.show()

# %%
# view light

plt.plot(sample_cmfs["wavelengths"], np.array(sample_light['D50']))
plt.show()

# %%
# print bayer type, mean of noise, sigma of noise

print(sample_bayer, sample_mean, sample_sigma)
# Out:
# GRBG [-0.65260406] [21]
